# %%
import xarray as xr
from Chemometrics.import_common import *
# %matplotlib inline
plt.rcParams['font.sans-serif'] = 'SimHei'

# %%
import glob

# %%
files = glob.glob('//192.168.1.192/Shares/Evelyn/mouse data/*.cdf')

# %%
ds = xr.open_dataset(files[0])

# %%
scans_indexs = np.vstack([ds.scan_index,ds.scan_index+ds.point_count])

# %%
index = np.s_[scans_indexs[0,0]:scans_indexs[1,0]]

# %%
X = np.random.randn(10, 10000)
sns.set(font_scale=1)
sns.heatmap(X, xticklabels=False)
# plt.plot(X.T)

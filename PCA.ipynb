# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot
# %matplotlib inline

# %%
# 生成数据
x = np.random.rand(300,1000)
w = np.random.rand(1,1000)
y = x.dot(w.T)+.01*np.random.rand(300,1)
